# %%
get-process
# Out:
#     Directory: C:\Users\sheng\powershell
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d----            2025/6/3    13:05                .ipynb_checkpoints
# d----            2025/6/3    12:49                learning
# d----           2025/5/29    18:15                newFeature
# d----           2025/5/27    10:40                powershell_cmd
# d----           2025/5/26     9:26                powershell_irm_dll
# d----           2025/5/26     9:39                windows_activate
# -a---           2025/5/26     9:21             12 .gitignore
# -a---           2025/5/26     9:43             66 README.md
# -a---            2025/6/3    13:05             72 Untitled.ipynb
#
# . {
# >> get-process
# >>
# >> }
# >>

# %%
get-command ls
# Out:
#  NPM(K)    PM(M)      WS(M)     CPU(s)      Id  SI ProcessName
#  ------    -----      -----     ------      --  -- -----------
#      39    54.69      92.73       4.69    1060   2 Acrobat
#      84   215.71     278.36      52.98   20824   2 Acrobat
#      17     7.96      21.20       0.02    1552   2 AcroCEF
#      22    42.84      82.18       1.48    2332   2 AcroCEF
#      34    18.64      66.45       2.78    4516   2 AcroCEF
#      21    34.33      72.55       1.19    7320   2 AcroCEF
#      21    33.40      69.16       0.59    9584   2 AcroCEF
#      21     9.80      29.93       0.58   10016   2 AcroCEF
#      21    33.48      69.16       0.50   16528   2 AcroCEF
#      35   165.78     118.51       0.94   18964   2 AcroCEF
#      21    39.28      75.32       0.83   22384   2 AcroCEF
#      15     7.49      18.52       0.12    2800   2 AdobeCollabSync
#      19    10.05      24.70       0.11    9628   2 AdobeCollabSync
# ...

# %%
get-date
# Out:
# 2025■6■3■ 13:06:41
